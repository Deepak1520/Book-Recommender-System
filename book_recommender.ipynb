# %%
import pandas as pd
import numpy as np

# %%
books = pd.read_csv('data/Books.csv', low_memory = False)
ratings = pd.read_csv('data/Ratings.csv')
users = pd.read_csv('data/Users.csv')

# %%
books.head()
# Out:
#          ISBN                                         Book-Title  \
# 0  0195153448                                Classical Mythology
# 1  0002005018                                       Clara Callan
# 2  0060973129                               Decision in Normandy
# 3  0374157065  Flu: The Story of the Great Influenza Pandemic...
# 4  0393045218                             The Mummies of Urumchi
#
#             Book-Author Year-Of-Publication                   Publisher  \
# 0    Mark P. O. Morford                2002     Oxford University Press
# 1  Richard Bruce Wright                2001       HarperFlamingo Canada
# 2          Carlo D'Este                1991             HarperPerennial
# 3      Gina Bari Kolata                1999        Farrar Straus Giroux
# 4       E. J. W. Barber                1999  W. W. Norton &amp; Company
#
#                                          Image-URL-S  \
# 0  http://images.amazon.com/images/P/0195153448.0...
# ...

# %%
ratings.head()
# Out:
#    User-ID        ISBN  Book-Rating
# 0   276725  034545104X            0
# 1   276726  0155061224            5
# 2   276727  0446520802            0
# 3   276729  052165615X            3
# 4   276729  0521795028            6

# %%
users.head()
# Out:
#    User-ID                            Location   Age
# 0        1                  nyc, new york, usa   NaN
# 1        2           stockton, california, usa  18.0
# 2        3     moscow, yukon territory, russia   NaN
# 3        4           porto, v.n.gaia, portugal  17.0
# 4        5  farnborough, hants, united kingdom   NaN

# %%
print(books.shape)
print(ratings.shape)
print(users.shape)
# Out:
# (271360, 8)
# (1149780, 3)
# (278858, 3)

# %% [markdown]
# # Counting missing values in each column of the dataset

# %%
books.isnull().sum()
# Out:
# ISBN                   0
# Book-Title             0
# Book-Author            1
# Year-Of-Publication    0
# Publisher              2
# Image-URL-S            0
# Image-URL-M            0
# Image-URL-L            3
# dtype: int64

# %%
users.isnull().sum()
# Out:
# User-ID          0
# Location         0
# Age         110762
# dtype: int64

# %%
ratings.isnull().sum()
# Out:
# User-ID        0
# ISBN           0
# Book-Rating    0
# dtype: int64

# %%
ratings.columns
# Out:
# Index(['User-ID', 'ISBN', 'Book-Rating'], dtype='object')

# %%
books.columns
# Out:
# Index(['ISBN', 'Book-Title', 'Book-Author', 'Year-Of-Publication', 'Publisher',
#        'Image-URL-S', 'Image-URL-M', 'Image-URL-L'],
#       dtype='object')

# %%
users.columns
# Out:
# Index(['User-ID', 'Location', 'Age'], dtype='object')

# %% [markdown]
# # Plotting the distribution of ratings

# %%
import matplotlib.pyplot as plt

# %%
plt.hist(ratings['Book-Rating'], bins = 10)
plt.xlabel('Rating')
plt.ylabel('Frequency')
plt.title('Distribution of Ratings')
plt.show()

# %% [markdown]
# # Finding the top rated books by aggregating the rating data by book

# %%
top_rated_books = ratings.groupby('ISBN')['Book-Rating'].mean().sort_values(ascending = False)
top_rated_books.head(10)
# Out:
# ISBN
# 0874477050    10.0
# 561002010     10.0
# 0590939874    10.0
# 1570761914    10.0
# 56500624X     10.0
# 157076154X    10.0
# 1570761175    10.0
# 0373510365    10.0
# 0393092526    10.0
# 0590936026    10.0
# Name: Book-Rating, dtype: float64

# %% [markdown]
# # Finding the most popular authors by aggregating the book data by author

# %%
popular_authors = books.groupby('Book-Author')['ISBN'].count().sort_values(ascending = False)
popular_authors.head()
# Out:
# Book-Author
# Agatha Christie        632
# William Shakespeare    567
# Stephen King           524
# Ann M. Martin          423
# Carolyn Keene          373
# Name: ISBN, dtype: int64

# %% [markdown]
# # Building a popularity based recommendation system

# %%
ratings_with_name = ratings.merge(books, on = "ISBN")
ratings_with_name
# Out:
#          User-ID        ISBN  Book-Rating  \
# 0         276725  034545104X            0
# 1           2313  034545104X            5
# 2           6543  034545104X            0
# 3           8680  034545104X            5
# 4          10314  034545104X            9
# ...          ...         ...          ...
# 1031131   276688  0517145553            0
# 1031132   276688  1575660792            7
# 1031133   276690  0590907301            0
# 1031134   276704  0679752714            0
# 1031135   276704  0806917695            5
#
#                                                 Book-Title      Book-Author  \
# 0                                     Flesh Tones: A Novel       M. J. Rose
# 1                                     Flesh Tones: A Novel       M. J. Rose
# 2                                     Flesh Tones: A Novel       M. J. Rose
# 3                                     Flesh Tones: A Novel       M. J. Rose
# ...

# %%
num_rating_df = ratings_with_name.groupby('Book-Title').count()['Book-Rating'].reset_index()
num_rating_df
# Out:
#                                                Book-Title  Book-Rating
# 0        A Light in the Storm: The Civil War Diary of ...            4
# 1                                   Always Have Popsicles            1
# 2                    Apple Magic (The Collector's series)            1
# 3        Ask Lily (Young Women of Faith: Lily Series, ...            1
# 4        Beyond IBM: Leadership Marketing and Finance ...            1
# ...                                                   ...          ...
# 241066                                      Ã?Â?lpiraten.            2
# 241067                     Ã?Â?rger mit Produkt X. Roman.            4
# 241068                                Ã?Â?sterlich leben.            1
# 241069                              Ã?Â?stlich der Berge.            3
# 241070                                  Ã?Â?thique en toc            2
#
# [241071 rows x 2 columns]

# %%
num_rating_df.rename(columns={'Book-Rating':'Num-Ratings'}, inplace = True)
num_rating_df
# Out:
#                                                Book-Title  Num-Ratings
# 0        A Light in the Storm: The Civil War Diary of ...            4
# 1                                   Always Have Popsicles            1
# 2                    Apple Magic (The Collector's series)            1
# 3        Ask Lily (Young Women of Faith: Lily Series, ...            1
# 4        Beyond IBM: Leadership Marketing and Finance ...            1
# ...                                                   ...          ...
# 241066                                      Ã?Â?lpiraten.            2
# 241067                     Ã?Â?rger mit Produkt X. Roman.            4
# 241068                                Ã?Â?sterlich leben.            1
# 241069                              Ã?Â?stlich der Berge.            3
# 241070                                  Ã?Â?thique en toc            2
#
# [241071 rows x 2 columns]

# %%
avg_rating_df = ratings_with_name.groupby('Book-Title').mean()['Book-Rating'].reset_index()
print(avg_rating_df.head(10))
print(avg_rating_df.shape)
# Out:
#                                           Book-Title  Book-Rating
# 0   A Light in the Storm: The Civil War Diary of ...         2.25
# 1                              Always Have Popsicles         0.00
# 2               Apple Magic (The Collector's series)         0.00
# 3   Ask Lily (Young Women of Faith: Lily Series, ...         8.00
# 4   Beyond IBM: Leadership Marketing and Finance ...         0.00
# 5   Clifford Visita El Hospital (Clifford El Gran...         0.00
# 6                                       Dark Justice        10.00
# 7                                           Deceived         0.00
# 8   Earth Prayers From around the World: 365 Pray...         5.00
# 9   Final Fantasy Anthology: Official Strategy Gu...         5.00
# (241071, 2)

# %%
avg_rating_df.rename(columns = {'Book-Rating':'Average-Rating'}, inplace = True)
print(avg_rating_df.head(10))
print(avg_rating_df.shape)
# Out:
#                                           Book-Title  Average-Rating
# 0   A Light in the Storm: The Civil War Diary of ...            2.25
# 1                              Always Have Popsicles            0.00
# 2               Apple Magic (The Collector's series)            0.00
# 3   Ask Lily (Young Women of Faith: Lily Series, ...            8.00
# 4   Beyond IBM: Leadership Marketing and Finance ...            0.00
# 5   Clifford Visita El Hospital (Clifford El Gran...            0.00
# 6                                       Dark Justice           10.00
# 7                                           Deceived            0.00
# 8   Earth Prayers From around the World: 365 Pray...            5.00
# 9   Final Fantasy Anthology: Official Strategy Gu...            5.00
# (241071, 2)

# %%
popular_df = num_rating_df.merge(avg_rating_df, on = 'Book-Title')
print(popular_df.head())
print(popular_df.shape)
# Out:
#                                           Book-Title  Num-Ratings  \
# 0   A Light in the Storm: The Civil War Diary of ...            4
# 1                              Always Have Popsicles            1
# 2               Apple Magic (The Collector's series)            1
# 3   Ask Lily (Young Women of Faith: Lily Series, ...            1
# 4   Beyond IBM: Leadership Marketing and Finance ...            1
#
#    Average-Rating
# 0            2.25
# 1            0.00
# 2            0.00
# 3            8.00
# 4            0.00
# (241071, 3)

# %%
popular_df = popular_df[popular_df['Num-Ratings']>=250].sort_values('Average-Rating', ascending = False).head(50)

# %%
popular_df
# Out:
#                                                Book-Title  Num-Ratings  \
# 80434   Harry Potter and the Prisoner of Azkaban (Book 3)          428
# 80422        Harry Potter and the Goblet of Fire (Book 4)          387
# 80441      Harry Potter and the Sorcerer's Stone (Book 1)          278
# 80426   Harry Potter and the Order of the Phoenix (Boo...          347
# 80414    Harry Potter and the Chamber of Secrets (Book 2)          556
# 191612  The Hobbit : The Enchanting Prelude to The Lor...          281
# 187377  The Fellowship of the Ring (The Lord of the Ri...          368
# 80445   Harry Potter and the Sorcerer's Stone (Harry P...          575
# 211384     The Two Towers (The Lord of the Rings, Part 2)          260
# 219741                              To Kill a Mockingbird          510
# 183573                                  The Da Vinci Code          898
# 187880                 The Five People You Meet in Heaven          430
# ...

# %%
popular_df = popular_df.merge(books, on = 'Book-Title').drop_duplicates('Book-Title')[['Book-Title','Book-Author','Image-URL-M','Num-Ratings','Average-Rating']]

# %%
popular_df
# Out:
#                                             Book-Title  \
# 0    Harry Potter and the Prisoner of Azkaban (Book 3)
# 3         Harry Potter and the Goblet of Fire (Book 4)
# 5       Harry Potter and the Sorcerer's Stone (Book 1)
# 9    Harry Potter and the Order of the Phoenix (Boo...
# 13    Harry Potter and the Chamber of Secrets (Book 2)
# 16   The Hobbit : The Enchanting Prelude to The Lor...
# 17   The Fellowship of the Ring (The Lord of the Ri...
# 26   Harry Potter and the Sorcerer's Stone (Harry P...
# 28      The Two Towers (The Lord of the Rings, Part 2)
# 39                               To Kill a Mockingbird
# 47                                   The Da Vinci Code
# 53                  The Five People You Meet in Heaven
# 55                              The Catcher in the Rye
# 62                           The Lovely Bones: A Novel
# 63                                                1984
# 72                            Prodigal Summer: A Novel
# ...

# %% [markdown]
# # Collaborative Filtering Based Recommender System

# %%
x = ratings_with_name.groupby('User-ID').count()['Book-Rating'] > 200
user_rates = x[x].index

# %%
filtered_rating = ratings_with_name[ratings_with_name['User-ID'].isin(user_rates)]

# %%
y = filtered_rating.groupby('Book-Title').count()['Book-Rating']>=50
books_rated = y[y].index

# %%
final_ratings = filtered_rating[filtered_rating['Book-Title'].isin(books_rated)]

# %%
pt = final_ratings.pivot_table(index = 'Book-Title', columns = 'User-ID', values = 'Book-Rating')

# %%
pt.fillna(0, inplace = True)

# %%
pt
# Out:
# User-ID                                             254     2276    2766    \
# Book-Title
# 1984                                                   9.0     0.0     0.0
# 1st to Die: A Novel                                    0.0     0.0     0.0
# 2nd Chance                                             0.0    10.0     0.0
# 4 Blondes                                              0.0     0.0     0.0
# A Bend in the Road                                     0.0     0.0     7.0
# ...                                                    ...     ...     ...
# Year of Wonders                                        0.0     0.0     0.0
# You Belong To Me                                       0.0     0.0     0.0
# Zen and the Art of Motorcycle Maintenance: An I...     0.0     0.0     0.0
# Zoya                                                   0.0     0.0     0.0
# \O\" Is for Outlaw"                                    0.0     0.0     0.0
#
# ...

# %%
from sklearn.metrics.pairwise import cosine_similarity

# %%
similarity_score = cosine_similarity(pt)
similarity_score
# Out:
# array([[1.        , 0.10255025, 0.01220856, ..., 0.12110367, 0.07347567,
#         0.04316046],
#        [0.10255025, 1.        , 0.2364573 , ..., 0.07446129, 0.16773875,
#         0.14263397],
#        [0.01220856, 0.2364573 , 1.        , ..., 0.04558758, 0.04938579,
#         0.10796119],
#        ...,
#        [0.12110367, 0.07446129, 0.04558758, ..., 1.        , 0.07085128,
#         0.0196177 ],
#        [0.07347567, 0.16773875, 0.04938579, ..., 0.07085128, 1.        ,
#         0.10602962],
#        [0.04316046, 0.14263397, 0.10796119, ..., 0.0196177 , 0.10602962,
#         1.        ]])

# %%
def recommend(book_name):
    #fetch index from book name
    index = np.where(pt.index == book_name)[0][0]
    similar_items = sorted(list(enumerate(similarity_score[0])), key = lambda x:x[1], reverse = True)[1:6]
    
    for i in similar_items:
        print(pt.index[i[0]])

# %%
recommend('1984')
# Out:
# Animal Farm
# The Handmaid's Tale
# Brave New World
# The Vampire Lestat (Vampire Chronicles, Book II)
# The Hours : A Novel

# %%
import pickle

# %%
pickle.dump(popular_df, open('popular.pkl','wb'))
